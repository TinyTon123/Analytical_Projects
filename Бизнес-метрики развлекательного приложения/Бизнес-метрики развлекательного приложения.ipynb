# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Изучение-и-предобработка-исходных-данных" data-toc-modified-id="Изучение-и-предобработка-исходных-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Изучение и предобработка исходных данных</a></span></li><li><span><a href="#Функции-для-расчетов-и-визуализации-метрик" data-toc-modified-id="Функции-для-расчетов-и-визуализации-метрик-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Функции для расчетов и визуализации метрик</a></span><ul class="toc-item"><li><span><a href="#Пользовательские-профили" data-toc-modified-id="Пользовательские-профили-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Пользовательские профили</a></span></li><li><span><a href="#Процент-платящих" data-toc-modified-id="Процент-платящих-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Процент платящих</a></span></li><li><span><a href="#Сглаживание-данных" data-toc-modified-id="Сглаживание-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Сглаживание данных</a></span></li><li><span><a href="#Расчет-LTV-и-ROI" data-toc-modified-id="Расчет-LTV-и-ROI-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расчет LTV и ROI</a></span></li><li><span><a href="#Визуализация-LTV,-CAC-и-ROI" data-toc-modified-id="Визуализация-LTV,-CAC-и-ROI-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Визуализация LTV, CAC и ROI</a></span></li><li><span><a href="#Расчет-конверсии" data-toc-modified-id="Расчет-конверсии-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Расчет конверсии</a></span></li><li><span><a href="#Визуализация-конверсии" data-toc-modified-id="Визуализация-конверсии-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Визуализация конверсии</a></span></li><li><span><a href="#Расчет-удержания" data-toc-modified-id="Расчет-удержания-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Расчет удержания</a></span></li><li><span><a href="#Визуализация-удержания" data-toc-modified-id="Визуализация-удержания-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Визуализация удержания</a></span></li></ul></li><li><span><a href="#Расчеты" data-toc-modified-id="Расчеты-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Расчеты</a></span><ul class="toc-item"><li><span><a href="#Создание-профилей-пользователей" data-toc-modified-id="Создание-профилей-пользователей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Создание профилей пользователей</a></span></li><li><span><a href="#Период-привлечения-пользователей" data-toc-modified-id="Период-привлечения-пользователей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Период привлечения пользователей</a></span></li><li><span><a href="#Процент-платящих-пользователей" data-toc-modified-id="Процент-платящих-пользователей-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Процент платящих пользователей</a></span></li><li><span><a href="#Траты-на-рекламу" data-toc-modified-id="Траты-на-рекламу-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Траты на рекламу</a></span></li><li><span><a href="#Стоимость-привлечения-пользователя-(CAC)" data-toc-modified-id="Стоимость-привлечения-пользователя-(CAC)-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Стоимость привлечения пользователя (CAC)</a></span></li><li><span><a href="#Доход-(LTV)-и-прибыль-(ROI)-от-клиентов" data-toc-modified-id="Доход-(LTV)-и-прибыль-(ROI)-от-клиентов-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Доход (LTV) и прибыль (ROI) от клиентов</a></span></li><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Конверсия</a></span></li><li><span><a href="#Удержание" data-toc-modified-id="Удержание-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Удержание</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#Результаты-исследования" data-toc-modified-id="Результаты-исследования-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Результаты исследования</a></span></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование бизнес-метрик развлекательного приложения

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Развлекательное приложение, несмотря на огромные вложения в рекламу, в течение нескольких месяцев терпит убытки. <b>Необходимо разобраться в причинах и помочь компании выйти в плюс</b>.
#
# Для исследования <b>даются данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года</b>:
# - лог сервера с данными об их посещениях;
# - выгрузка их покупок за этот период;
# - рекламные расходы.
#
# <b>В процессе исследования выясним</b>:
# - откуда приходят пользователи и какими устройствами они пользуются;
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент;
# - когда расходы на привлечение клиента окупаются;
# - какие факторы мешают привлечению клиентов.
#
# <b>Набор данных</b>:
#
# Файл visits_info_short.csv, хранящий лог сервера с информацией о посещениях сайта. Структура файла:
# - User Id — уникальный идентификатор пользователя;
# - Region — страна пользователя;
# - Device — тип устройства пользователя;
# - Channel — идентификатор источника перехода;
# - Session Start — дата и время начала сессии;
# - Session End — дата и время окончания сессии.
#
# Файл orders_info_short.csv с информацией о покупках. Структура:
# - User Id — уникальный идентификатор пользователя;
# - Event Dt — дата и время покупки;
# - Revenue — сумма заказа.
#
# Файл costs_info_short.csv с информацией о расходах на рекламу. Структура:
# - Channel — идентификатор рекламного источника;
# - Dt — дата проведения рекламной кампании;
# - Costs — расходы на эту кампанию.

# %% [markdown]
# ## Изучение и предобработка исходных данных

# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
visits, orders, costs = pd.read_csv('/datasets/visits_info_short.csv',\
                                    parse_dates=['Session Start', 'Session End']),\
                        pd.read_csv('/datasets/orders_info_short.csv',\
                                    parse_dates=['Event Dt']),\
                        pd.read_csv('/datasets/costs_info_short.csv')

# %%
visits
# Out:
#              User Id         Region   Device         Channel  \
# 0       981449118918  United States   iPhone         organic
# 1       278965908054  United States   iPhone         organic
# 2       590706206550  United States      Mac         organic
# 3       326433527971  United States  Android          TipTop
# 4       349773784594  United States      Mac         organic
# ...              ...            ...      ...             ...
# 309896  329994900775             UK       PC         LeapBob
# 309897  334903592310         France       PC  lambdaMediaAds
# 309898  540102010126        Germany       PC         organic
# 309899  308736936846        Germany      Mac         organic
# 309900  109329042535        Germany       PC  lambdaMediaAds
#
#              Session Start         Session End
# 0      2019-05-01 02:36:01 2019-05-01 02:45:01
# 1      2019-05-01 04:46:31 2019-05-01 04:47:35
# 2      2019-05-01 14:09:25 2019-05-01 15:32:08
# ...

# %% [markdown]
# Переименуем столбцы

# %%
visits.columns = visits.columns.str.lower().str.replace(' ', '_')
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %% [markdown]
# Узнаем, есть ли дубликаты явные...

# %%
visits.loc[visits.duplicated()].count()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %% [markdown]
# .. и неявные в текстовых столбцах.

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
visits['device'].unique()
# Out:
# array(['iPhone', 'Mac', 'Android', 'PC'], dtype=object)

# %%
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
orders
# Out:
#             User Id            Event Dt  Revenue
# 0      188246423999 2019-05-01 23:09:52     4.99
# 1      174361394180 2019-05-01 12:24:04     4.99
# 2      529610067795 2019-05-01 11:34:04     4.99
# 3      319939546352 2019-05-01 15:34:40     4.99
# 4      366000285810 2019-05-01 13:59:51     4.99
# ...             ...                 ...      ...
# 40207  651604369137 2019-10-31 16:19:07     4.99
# 40208  275341387049 2019-10-31 01:17:17     4.99
# 40209  374656616484 2019-10-31 06:17:29     4.99
# 40210  168548862926 2019-10-31 22:46:19     4.99
# 40211  329994900775 2019-10-31 13:29:06     4.99
#
# [40212 rows x 3 columns]

# %%
orders.columns = orders.columns.str.lower().str.replace(' ', '_')
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
orders.describe()
# Out:
#             user_id       revenue
# count  4.021200e+04  40212.000000
# mean   4.990295e+11      5.370608
# std    2.860937e+11      3.454208
# min    5.993260e+05      4.990000
# 25%    2.511324e+11      4.990000
# 50%    4.982840e+11      4.990000
# 75%    7.433327e+11      4.990000
# max    9.998954e+11     49.990000

# %%
orders.loc[orders.duplicated()].count()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
costs
# Out:
#               dt         Channel  costs
# 0     2019-05-01        FaceBoom  113.3
# 1     2019-05-02        FaceBoom   78.1
# 2     2019-05-03        FaceBoom   85.8
# 3     2019-05-04        FaceBoom  136.4
# 4     2019-05-05        FaceBoom  122.1
# ...          ...             ...    ...
# 1795  2019-10-23  lambdaMediaAds    4.0
# 1796  2019-10-24  lambdaMediaAds    6.4
# 1797  2019-10-25  lambdaMediaAds    8.8
# 1798  2019-10-26  lambdaMediaAds    8.8
# 1799  2019-10-27  lambdaMediaAds   12.0
#
# [1800 rows x 3 columns]

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
costs.columns = costs.columns.str.lower().str.replace(' ', '_')
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.loc[costs.duplicated()].count()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %%
costs.describe()
# Out:
#              costs
# count  1800.000000
# mean     58.609611
# std     107.740223
# min       0.800000
# 25%       6.495000
# 50%      12.285000
# 75%      33.600000
# max     630.000000

# %%
costs['channel'].unique()
# Out:
# array(['FaceBoom', 'MediaTornado', 'RocketSuperAds', 'TipTop', 'YRabbit',
#        'AdNonSense', 'LeapBob', 'OppleCreativeMedia', 'WahooNetBanner',
#        'lambdaMediaAds'], dtype=object)

# %% [markdown]
# ## Функции для расчетов и визуализации метрик

# %% [markdown]
# ### Пользовательские профили

# %%
def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Процент платящих

# %%
def profiles_grouped(df, param):
    profiles_by = df.groupby(param).agg({'user_id': 'count'}).reset_index().rename(columns={
                                'user_id': 'user_count'})
    profiles_by = profiles_by.merge(profiles.query('payer == True')
                                                              .groupby(param).agg({'user_id': 'count'})
                                                              .reset_index().rename(columns={
                                                              'user_id': 'payers_count'}), on=param)
    profiles_by['paying_percent'] = profiles_by['payers_count'] / profiles_by['user_count'] * 100
    return profiles_by.sort_values(by='paying_percent', ascending=False)

# %% [markdown]
# ### Сглаживание данных

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Расчет LTV и ROI

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Визуализация LTV, CAC и ROI

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(5, 1, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(5, 1, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(5, 1, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(5, 1, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(5, 1, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5, figsize=(15,30))
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.show()

# %% [markdown]
# ### Расчет конверсии

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Визуализация конверсии

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(2, 1, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(2, 1, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2, figsize=(15,15))
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.show()

# %% [markdown]
# ### Расчет удержания

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Визуализация удержания

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(4, 1, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(4, 1, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(4, 1, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(4, 1, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4, figsize=(15,25))
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.show()

# %% [markdown]
# ## Расчеты

# %% [markdown]
# ### Создание профилей пользователей

# %% [markdown]
# Создадим таблицу с профилями пользователей, которые включают информацию о первом визите, канале привлечения, устройстве и стране пользователя, а также о том, является ли пользователь плательщиком и сколько стоило привлечение пользователя.

# %%
profiles = get_profiles(visits, orders, costs)
profiles
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %% [markdown]
# ### Период привлечения пользователей

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей

# %%
date = visits['session_start'].dt.date
min_date = str(date.min())
print (f'Минимальная дата привлечения пользователей: {min_date}')

max_date = str(date.max())
print (f'Максимальная дата привлечения пользователей: {max_date}')
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01
# Максимальная дата привлечения пользователей: 2019-10-31

# %% [markdown]
# ### Процент платящих пользователей

# %% [markdown]
# Найдем процент платящих пользователей в разбивке по странам

# %%
profiles_grouped(profiles, 'region')
# Out:
#           region  user_count  payers_count  paying_percent
# 3  United States      100002          6902        6.901862
# 1        Germany       14981           616        4.111875
# 2             UK       17575           700        3.982930
# 0         France       17450           663        3.799427

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# По абсолютному количеству платящих пользователей с большим отрывом лидируют США — 6900 из ста тысяч. Процент платящих из этой страны тоже самый высокий — почти 7 процентов. На нижней строчке — Франция (3,8% платящих).

# %% [markdown]
# Процент платящих в разбивке по устройствам

# %%
profiles_grouped(profiles, 'device')
# Out:
#     device  user_count  payers_count  paying_percent
# 1      Mac       30042          1912        6.364423
# 3   iPhone       54479          3382        6.207897
# 0  Android       35032          2050        5.851793
# 2       PC       30455          1537        5.046790

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Больше всего платящих пользователей — владельцы iPhone (3,3 тыс. из 54,5 тыс., или 6,2%). В процентном отношении лидируют устройства Mac — 6,4 процента пользователей конвертируются в платящих. В низах — PC (5% платящих).

# %% [markdown]
# Процент платящих в разбивке по каналу привлечения

# %%
profiles_grouped(profiles, 'channel')
# Out:
#                channel  user_count  payers_count  paying_percent
# 1             FaceBoom       29144          3557       12.204914
# 0           AdNonSense        3880           440       11.340206
# 9       lambdaMediaAds        2149           225       10.469986
# 6               TipTop       19561          1878        9.600736
# 5       RocketSuperAds        4448           352        7.913669
# 7       WahooNetBanner        8553           453        5.296387
# 8              YRabbit        4312           165        3.826531
# 3         MediaTornado        4364           156        3.574702
# 2              LeapBob        8553           262        3.063253
# 4   OppleCreativeMedia        8605           233        2.707728
# 10             organic       56439          1160        2.055316

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Среди каналов привлечения по числу и проценту платящих пользователей лидирует FaceBoom — 3,5 тыс. из 29,1 тыс., или 12,2%. Далее идут AdNonSense (11,3%) и lambdaMediaAds (10,5%).

# %% [markdown]
# ### Траты на рекламу

# %% [markdown]
# Общие траты на рекламу

# %%
costs_sum = round(costs['costs'].sum())
print(f'Общие траты на рекламу составили ${costs_sum}')
# Out:
# Общие траты на рекламу составили $105497

# %% [markdown]
# Разбивка трат по каналу привлечения

# %%
costs_by_channel = costs.groupby('channel')['costs'].sum().sort_values(ascending=False).reset_index()
costs_by_channel['percentage'] = round(costs_by_channel['costs'] / costs_sum * 100, 2)
costs_by_channel
# Out:
#               channel     costs  percentage
# 0              TipTop  54751.30       51.90
# 1            FaceBoom  32445.60       30.75
# 2      WahooNetBanner   5151.00        4.88
# 3          AdNonSense   3911.25        3.71
# 4  OppleCreativeMedia   2151.25        2.04
# 5      RocketSuperAds   1833.00        1.74
# 6             LeapBob   1797.60        1.70
# 7      lambdaMediaAds   1557.60        1.48
# 8        MediaTornado    954.48        0.90
# 9             YRabbit    944.22        0.90

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Более половины рекламного бюджета ушло на канал привлечения TipTop — 54,7 тыс. долл., или 51,9 проц. бюджета. Треть бюджета ушла на FaceBoom (32,4 тыс. долл., или 30,8 проц.).

# %% [markdown]
# Исключаем "органических" пользователей — тех, кто пришел без рекламы.

# %%
profiles_wo_organic = profiles.query('channel != "organic"')
profiles_wo_organic
# Out:
#              user_id            first_ts       channel   device  \
# 0             599326 2019-05-07 20:58:57      FaceBoom      Mac
# 1            4919697 2019-07-09 12:46:07      FaceBoom   iPhone
# 3           22593348 2019-08-22 21:35:48    AdNonSense       PC
# 4           31989216 2019-10-02 00:07:44       YRabbit   iPhone
# 7           46006712 2019-06-30 03:46:29    AdNonSense  Android
# ...              ...                 ...           ...      ...
# 149999  999942424543 2019-05-24 21:03:26        TipTop   iPhone
# 150001  999949280903 2019-08-12 06:47:27      FaceBoom      Mac
# 150003  999956196527 2019-09-28 08:33:02        TipTop   iPhone
# 150005  999976332130 2019-07-23 02:57:06        TipTop   iPhone
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado       PC
#
#                region          dt      month  payer  acquisition_cost
# 0       United States  2019-05-07 2019-05-01   True          1.088172
# ...

# %% [markdown]
# ### Стоимость привлечения пользователя (CAC)

# %% [markdown]
# Динамика стоимости привлечения в целом по проекту за все время

# %%
profiles_wo_organic.pivot_table(
                                index='dt',
                                values='acquisition_cost',
                                aggfunc='mean'
                               ).plot(grid=True, figsize=(16, 8))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС в целом по проекту')
plt.show()

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Заметно, что практически на протяжении всего исследуемого периода стоимость привлечения пользователя ощутимо росла.

# %% [markdown]
# Динамика САС в разбивке по каналам привлечения

# %%
profiles_wo_organic.pivot_table(
                                index='dt',
                                columns='channel',
                                values='acquisition_cost',
                                aggfunc='mean'
                               ).plot(grid=True, figsize=(16, 8))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Из графика становится понятно, что увеличение стоимости привлечения пользователя происходило из-за увеличения рекламы в TipTop. Расходы на остальные каналы привлечения не увеличивались с течением времени.

# %% [markdown]
# ### Доход (LTV) и прибыль (ROI) от клиентов

# %% [markdown]
# Общие LTV и ROI

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14
                                                     )

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=7)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# В целом маркетинг проекта убыточен — возврат с инвестиций (ROI) оказался на уровне 80%. Привлечение пользователей окупалось только в первый месяц. Затем показатель ROI упал ниже единицы.

# %% [markdown]
# LTV, CAC и ROI в разбивке по каналам привлечения

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14,
                                                        dimensions=['channel']
                                                     )

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=21)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Наибольший доход принесли пользователи, привлеченные через каналы lambdaMediaAds и TipTop, как в целом по проекту, так и в динамике за исследуемый период.
#
# Самым убыточным с точки зрения возврата инвестиций оказался канал привлечения TipTop. Затем — FaceBoom и AdNonSense. Самый прибыльный — YRabbit.

# %% [markdown]
# LTV, CAC и ROI в разбивке по странам

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14,
                                                        dimensions=['region']
                                                     )

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, 14, window=7)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Наиболее платящие пользователи — из США, наименее — из Франции. Стоимость привлечения пользователей из США резко возросла в начале исследуемого периода, тогда как в других странах наоборот снизилась. Из-за этого окупаемость пользователей из США ниже единицы, то есть они приносят убытки. Пользователи из других стран прибыльны для проекта.

# %% [markdown]
# ### Конверсия

# %% [markdown]
# Конверсия по каналам привлечения

# %%
conv_raw, conv_grouped, conv_in_time = get_conversion(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14,
                                                        dimensions=['channel']
                                                     )

plot_conversion(conv_grouped, conv_in_time, 14, window=21)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Лидеры по конверсии пользователей — следующие каналы привлечения: FaceBoom, AdNonSense, lambdaMediaAds. В низу списка — OppleCreativeMedia, LeapBob, MediaTornado, YRabbit.

# %% [markdown]
# Конверсия в разбивке по устройствам

# %%
conv_raw, conv_grouped, conv_in_time = get_conversion(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14,
                                                        dimensions=['device']
                                                     )

plot_conversion(conv_grouped, conv_in_time, 14, window=14)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# В лидерах по конверсии — Mac и iPhone. В лузерах - PC.

# %% [markdown]
# Конверсия в разбивке по странам

# %%
conv_raw, conv_grouped, conv_in_time = get_conversion(
                                                        profiles_wo_organic,
                                                        orders,
                                                        datetime(2019, 10, 31).date(),
                                                        14,
                                                        dimensions=['region']
                                                     )

plot_conversion(conv_grouped, conv_in_time, 14, window=14)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Конверсия в США почти в два раза выше этого показателя в других странах.

# %% [markdown]
# ### Удержание

# %% [markdown]
# Удержание в разбивке по каналам привлечения

# %%
ret_raw, ret_grouped, ret_in_time = get_retention(
                                                    profiles_wo_organic,
                                                    visits,
                                                    datetime(2019, 10, 31).date(),
                                                    14,
                                                    dimensions=['channel']
                                                 )

plot_retention(ret_grouped, ret_in_time, 14, window=7)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Удержание платящих пользователей, пришедших из большинства каналов привлечения, почти одинаковое, однако у двух — AdNonSense и FaceBoom — оно намного ниже остальных.

# %% [markdown]
# Удержание в разбивке по устройствам

# %%
ret_raw, ret_grouped, ret_in_time = get_retention(
                                                    profiles_wo_organic,
                                                    visits,
                                                    datetime(2019, 10, 31).date(),
                                                    14,
                                                    dimensions=['device']
                                                 )

plot_retention(ret_grouped, ret_in_time, 14, window=7)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Удержание платящих и неплатящих пользователей на всех устройствах почти одинаковое

# %% [markdown]
# Удержание в разбивке по странам

# %%
ret_raw, ret_grouped, ret_in_time = get_retention(
                                                    profiles_wo_organic,
                                                    visits,
                                                    datetime(2019, 10, 31).date(),
                                                    14,
                                                    dimensions=['region']
                                                 )

plot_retention(ret_grouped, ret_in_time, 14, window=7)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Удержание платящих пользователей в сравнении с другими странами "хромает" в США.

# %% [markdown]
# ## Выводы

# %% [markdown]
# ### Результаты исследования

# %% [markdown]
# В процессе выяснения причин, из-за которых развлекательное приложение, несмотря на огромные вложения в рекламу, в течение нескольких месяцев терпело убытки, мы исследовали данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - лог сервера с данными об их посещениях;
# - выгрузка их покупок за этот период;
# - рекламные расходы.
#
# <b>Результаты исследования</b>:
# - По абсолютному количеству платящих пользователей с большим отрывом лидируют США — 6900 из ста тысяч. Процент платящих из этой страны тоже самый высокий — почти 7 процентов. На нижней строчке — Франция (3,8% платящих).
# - Больше всего платящих пользователей — владельцы iPhone (3,3 тыс. из 54,5 тыс., или 6,2%). В процентном отношении лидируют устройства Mac — 6,4% пользователей конвертируются в платящих. В низах — PC (5% платящих).
# - Среди каналов привлечения по числу и проценту платящих пользователей лидирует FaceBoom — 3,5 тыс. из 29,1 тыс., или 12,2%. Далее идут AdNonSense (11,3%) и lambdaMediaAds (10,5%).
# - Более половины рекламного бюджета ушло на канал привлечения TipTop — 54,7 тыс. долл., или 51,9% бюджета. Треть бюджета ушло на FaceBoom (32,4 тыс. долл., или 30,8%).
# - Практически на протяжении всего исследуемого периода стоимость привлечения пользователя в целом ощутимо росла. На это повлияло в основном увеличение рекламы в TipTop. Расходы на остальные каналы привлечения не увеличивались с течением времени.
# - В целом маркетинг проекта убыточен — возврат с инвестиций (ROI) оказался на уровне 80%. Привлечение пользователей окупалось только в первый месяц. Затем показатель ROI упал ниже единицы.
# - Наибольший доход принесли пользователи, привлеченные через каналы lambdaMediaAds и TipTop, как в целом по проекту, так и в динамике за исследуемый период.
# - Самым убыточным с точки зрения возврата инвестиций оказался канал привлечения TipTop. Затем — FaceBoom и AdNonSense. Самый прибыльный — YRabbit.
# - Наиболее платящие пользователи — из США, наименее — из Франции. Стоимость привлечения пользователей из США резко возросла в начале исследуемого периода, тогда как в других странах наоборот снизилась. Из-за этого окупаемость пользователей из США ниже единицы, то есть они приносят убытки. Пользователи из других стран прибыльны для проекта.
# - Лидеры по конверсии пользователей — следующие каналы привлечения: FaceBoom, AdNonSense, lambdaMediaAds. В низу списка — OppleCreativeMedia, LeapBob, MediaTornado, YRabbit.
# - В лидерах по конверсии — Mac и iPhone. В лузерах — PC.
# - Конверсия в США почти в два раза выше этого показателя в других странах.
# - Удержание платящих пользователей, пришедших из большинства каналов привлечения, почти одинаковое, однако у двух — AdNonSense и FaceBoom — оно намного ниже остальных.
# - Удержание платящих и неплатящих пользователей на всех устройствах почти одинаковое.
# - Удержание платящих пользователей в сравнении с другими странами "хромает" в США.

# %% [markdown]
# ### Рекомендации

# %% [markdown]
# Основной причиной финансовых неудач развлекательного приложения является неоправданный рост расходов на привлечение пользователей через TipTop, на который было потрачено больше половины совокупного бюджета. Кроме того, хорошая конверсия и высокая доходность пользователей из США нивелируются большими затратами на их привлечение. В итоге пользователь из США стал невыгодным для приложения.
#
# Рекомемндации:
# - Перераспределить рекламный бюджет, отказавшись от TipTop в пользу YRabbit, MediaTornado и lambdaMediaAds — они наиболее прибыльные с точки зрения возврата на инвестицию.
# - Отказаться от рекламы в США в пользу других стран, где пользователи приносят прибыль.
